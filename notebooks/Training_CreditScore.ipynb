# %%
# Sklearn & Keras imports
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
import pandas as pd
import numpy as np

# DiCE imports
import dice_ml
from dice_ml.utils import helpers  # helper functions

# %%
dataset = pd.read_csv('german_credit_data (1).csv')
dataset[['Checking account','Saving accounts']] = dataset[['Checking account','Saving accounts']].fillna('')
LE = LabelEncoder()
display(dataset.head())
dataset['Risk'] = LE.fit_transform(dataset['Risk'])
dataset = dataset.drop(['Unnamed: 0'],axis=1)
dataset.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own                           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own                           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little                            2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV     1
# 1        48             radio/TV     0
# 2        12            education     1
# 3        42  furniture/equipment     1
# 4        24                  car     0

# %% [markdown]
# ## Data Modelling

# %%
dataset['Risk'].value_counts()
# Out:
# 1    700
# 0    300
# Name: Risk, dtype: int64

# %% [markdown]
# There is a slight data imbalance in the dataset. 70% are good and 30% are bad. Therefore, given data imbalances lead to overfitting, it is appropriate to take measures to balance the dataset (under/oversampling) and to evaluate by using a variety of metrics (as opposed to only accuracy)

# %% [markdown]
# ## Model Building

# %%
from collections import Counter


target = dataset["Risk"]
X = dataset.drop(['Risk'],axis=1)

ros = RandomUnderSampler()
# resampling X, y
dataset, target = ros.fit_resample(X, target)
# new class distribution 
print(Counter(target))
print(type(dataset))

dataset = pd.concat([dataset,target],axis=1)

train_dataset, test_dataset, y_train, y_test = train_test_split(dataset,
                                                                target,
                                                                test_size=0.2,
                                                                random_state=0,
                                                                stratify=target)
x_train = train_dataset.drop('Risk', axis=1)
x_test = test_dataset.drop('Risk', axis=1)
# Out:
# Counter({0: 300, 1: 300})
# <class 'pandas.core.frame.DataFrame'>

# %%
d = dice_ml.Data(dataframe=train_dataset, continuous_features=['Age','Credit amount','Duration'], outcome_name='Risk')

# %%
numerical = ['Credit amount','Duration']
categorical = x_train.columns.difference(numerical)

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

transformations = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical)])

# Append classifier to preprocessing pipeline.

clf_rf = Pipeline(steps=[('preprocessor', transformations),
                      ('clf', RandomForestClassifier(random_state=42))])

clf_svm = Pipeline(steps=[('preprocessor', transformations),
                      ('clf', SVC(random_state=42))])

grid_params_rf = [{'clf__criterion': ['gini', 'entropy'],
                   'clf__max_features': ['auto', 'sqrt'],
                   'clf__n_estimators': [int(x) for x in np.linspace(start = 128, stop = 384, num = 32)],
                   'clf__min_samples_split': [2, 5, 10],
                   'clf__max_depth': [int(x) for x in np.linspace(start = 5, stop = 8, num = 1)]}]

grid_params_svm = [{'clf__kernel': ['poly', 'rbf','sigmoid'], 
        'clf__C': [0.1, 1, 10, 100, 1000],
        'clf__gamma': [1, 0.1, 0.01, 0.001, 0.0001]}]

jobs = -1

RF = GridSearchCV(estimator=clf_rf,
            param_grid=grid_params_rf,
            scoring='roc_auc',
            cv=10, 
            n_jobs=jobs)


SVM = GridSearchCV(estimator=clf_svm,
            param_grid=grid_params_svm,
            scoring='roc_auc',
            cv=10,
            n_jobs=jobs)

grids = [RF,SVM]

# %%
# Creating a dict for our reference
grid_dict = {0: 'Random Forest', 
        1: 'Support Vector Machine'}

best_rf = {'score': 0, 'best_model':0}
best_svm = {'score': 0, 'best_model':0}

# Fit the grid search objects
print('Performing model optimizations...')

for idx, model in enumerate(grids):
    
    print('\nEstimator: %s' % grid_dict[idx])
    model.fit(x_train, y_train)
    print('Best params are : %s' % model.best_params_)
    
    # Best training data accuracy
    print('Best training accuracy: %.3f' % model.best_score_)
    
    # Predict on test data with best params
    y_pred = model.predict(x_test)
    print('Test set accuracy score for best params: %.3f ' % accuracy_score(y_test, y_pred))
    print('Precision score: {}'.format(precision_score(y_test, y_pred)))
    print('Recall score: {}'.format(recall_score(y_test, y_pred)))
    print('F1 score: {}'.format(f1_score(y_test, y_pred)))
    print('AUC-ROC score: {}'.format(roc_auc_score(y_test, y_pred)))
    
    # Track best (highest test accuracy) model
    if idx == 0:
        if roc_auc_score(y_test, y_pred) > best_rf['score']:
            best_rf['score'] = roc_auc_score(y_test, y_pred)
            best_rf['best_model'] = model.best_params_ 
    
    elif idx == 1:
        if roc_auc_score(y_test, y_pred) > best_svm['score']:
            best_svm['score'] = roc_auc_score(y_test, y_pred)
            best_svm['best_model'] = model.best_params_
            
# save dict to file
import json

with open('best_creditscore_rf_params.txt', 'w') as file:
     file.write(json.dumps(best_rf)) # use `json.loads` to do the reverse
        
with open('best_creditscore_svm_params.txt', 'w') as file:
     file.write(json.dumps(best_svm)) # use `json.loads` to do the reverse
# Out:
# Performing model optimizations...
#
# Estimator: Random Forest
# Best params are : {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__max_features': 'auto', 'clf__min_samples_split': 5, 'clf__n_estimators': 136}
# Best training accuracy: 0.728
# Test set accuracy score for best params: 0.725
# Precision score: 0.7454545454545455
# Recall score: 0.6833333333333333
# F1 score: 0.7130434782608696
# AUC-ROC score: 0.725
#
# Estimator: Support Vector Machine
# Best params are : {'clf__C': 0.1, 'clf__gamma': 0.1, 'clf__kernel': 'poly'}
# Best training accuracy: 0.734
# Test set accuracy score for best params: 0.742
# Precision score: 0.8222222222222222
# Recall score: 0.6166666666666667
# F1 score: 0.7047619047619048
# AUC-ROC score: 0.7416666666666667

# %%
rf_model = RandomForestClassifier()
svm_model = SVC()
rf_params = best_rf['best_model']
svm_params = best_svm['best_model']
rf_dict = {}
svm_dict = {}
print(rf_params)
print(svm_params)
for key in rf_params:
    rf_dict[key[5:]] = rf_params[key]
for key in svm_params:
    svm_dict[key[5:]] = svm_params[key]
print(svm_dict)
print(rf_dict)
rf_model.set_params(**rf_dict)
svm_model.set_params(**svm_dict)
# Out:
# {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__max_features': 'auto', 'clf__min_samples_split': 5, 'clf__n_estimators': 136}
# {'clf__C': 0.1, 'clf__gamma': 0.1, 'clf__kernel': 'poly'}
# {'C': 0.1, 'gamma': 0.1, 'kernel': 'poly'}
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 136}
# SVC(C=0.1, gamma=0.1, kernel='poly')

# %%
clf_rf = Pipeline(steps=[('preprocessor', transformations),
                      ('clf', rf_model)])

clf_svm = Pipeline(steps=[('preprocessor', transformations),
                      ('clf', svm_model)])

clf_rf.fit(x_train, y_train)

clf_svm.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['Age', 'Checking account', 'Housing', 'Job', 'Purpose',
#        'Saving accounts', 'Sex'],
#       dtype='object'))])),
#                 ('clf',
#                  RandomForestClassifier(max_depth=5, min_samples_split=5,
#                                         n_estimators=136))])

# %% [markdown]
# ## Obtain inaccurate classifications (in dataframe)

# %%
y_pred_rf = clf_rf.predict(x_test)

# %%
list_index = list(y_test.index.values)
list_labels = [i for i in y_test]

actual_class = []
pred_class = []
for i in range(120):
    a = (list_index[i],list_labels[i])
    b = (list_index[i],y_pred_rf[i])
    actual_class.append(a)
    pred_class.append(b)

# %%
wrong_class = []
for i in range(120):
    if pred_class[i][1] != actual_class[i][1]:
        a = (pred_class[i][0], pred_class[i][1])
        wrong_class.append(a)
        
print(len(wrong_class))
# Out:
# 33
# [(381, 0), (326, 0), (313, 0), (363, 0), (503, 0), (305, 0), (334, 0), (574, 0), (392, 0), (361, 0), (28, 1), (65, 1), (17, 1), (115, 1), (580, 0), (195, 1), (477, 0), (99, 1), (186, 1), (566, 0), (436, 0), (120, 1), (595, 0), (183, 1), (420, 0), (387, 0), (324, 0), (185, 1), (441, 0), (406, 0), (372, 0), (556, 0), (394, 0)]

# %%
list_indices = []
for i,j in wrong_class:
    list_indices.append(i)

# %%
print(list_indices)
# Out:
# [381, 326, 313, 363, 503, 305, 334, 574, 392, 361, 28, 65, 17, 115, 580, 195, 477, 99, 186, 566, 436, 120, 595, 183, 420, 387, 324, 185, 441, 406, 372, 556, 394]

# %%
#obtain all x_test that are wrong misclassified
df = x_test
for idx in x_test.index:
    if idx not in list_indices:
        df = df.drop(idx)

# %%
df.head()
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 381   37    male    1     own          little             rich           3949
# 326   46    male    2     own          little           little           2348
# 313   26  female    2    rent                           little           2812
# 363   36    male    3    free          little           little           1872
# 503   23  female    0    rent      quite rich         moderate           3758
#
#      Duration              Purpose
# 381        10                  car
# 326        36  furniture/equipment
# 313        24                  car
# 363         6  furniture/equipment
# 503        24             radio/TV

# %%
len(df)
# Out:
# 33

# %% [markdown]
# ## MODEL #1

# %%
# Using sklearn backend
m = dice_ml.Model(model=clf_rf, backend="sklearn")
# Using method=random for generating CFs
exp = dice_ml.Dice(d, m, method="random") #change to either 'genetic' or 'kdtree'

# %%
e1 = exp.generate_counterfactuals(df[0:], total_CFs=3, features_to_vary=['Job','Housing','Saving accounts','Credit amount','Duration','Purpose'])
e1.visualize_as_dataframe(show_only_changes=True)
# Out:
#  39%|███▉      | 13/33 [00:06<00:05,  3.47it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#  48%|████▊     | 16/33 [00:07<00:04,  3.96it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#  55%|█████▍    | 18/33 [00:07<00:03,  4.09it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#  58%|█████▊    | 19/33 [00:07<00:03,  4.04it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#  61%|██████    | 20/33 [00:08<00:03,  3.97it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#  67%|██████▋   | 22/33 [00:08<00:02,  3.71it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#  85%|████████▍ | 28/33 [00:10<00:01,  3.68it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#  91%|█████████ | 30/33 [00:10<00:00,  3.71it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
# 100%|██████████| 33/33 [00:11<00:00,  2.85it/s]
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   37  male    1     own          little             rich           3949
#
#    Duration Purpose  Risk
# 0        10     car     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -               -                -        5232.0        -
# 1   -   -   1       -      quite rich                -             -        -
# 2   -   -   -       -               -                -             -     29.0
#
#            Purpose Risk
# 0          repairs    1
# 1                -    1
# 2  vacation/others    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   46  male    2     own          little           little           2348
#
#    Duration              Purpose  Risk
# 0        36  furniture/equipment     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -             -     25.0
# 1   -   -   -       -                                -       15366.0        -
# 2   -   -   -       -                                -             -     16.0
#
#   Purpose Risk
# 0       -    1
# 1       -    1
# 2       -    1
# Query instance (original outcome : 0)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   26  female    2    rent                           little           2812
#
#    Duration Purpose  Risk
# 0        24     car     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   0     own               -                -             -        -
# 1   -   -   1     own               -                -             -        -
# 2   -   -   3     own               -                -             -        -
#
#                Purpose Risk
# 0             radio/TV    1
# 1  domestic appliances    1
# 2             radio/TV    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   36  male    3    free          little           little           1872
#
#    Duration              Purpose  Risk
# 0         6  furniture/equipment     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -     own                                -             -        -
# 1   -   -   -       -                                -             -        -
# 2   -   -   -    rent                                -             -        -
#
#                Purpose Risk
# 0                    -    1
# 1  domestic appliances    1
# 2                    -    1
# Query instance (original outcome : 0)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   23  female    0    rent      quite rich         moderate           3758
#
#    Duration   Purpose  Risk
# 0        24  radio/TV     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -             -        -
# 1   -   -   1       -                                -             -        -
# 2   -   -   -       -                                -             -     47.0
#
#   Purpose Risk
# 0       -    1
# 1       -    1
# 2       -    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   29  male    2     own          little         moderate           2629
#
#    Duration          Purpose  Risk
# 0        20  vacation/others     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -       10345.0        -
# 1   -   -   -       -                                -        7376.0        -
# 2   -   -   -       -                                -             -        -
#
#    Purpose Risk
# 0        -    1
# 1        -    1
# 2  repairs    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   36  male    2     own          little           little           1721
#
#    Duration Purpose  Risk
# 0        15     car     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -      quite rich                -             -        -
# 1   -   -   -       -                                -             -        -
# 2   -   -   -       -                                -             -        -
#
#                Purpose Risk
# 0  domestic appliances    1
# 1              repairs    1
# 2  domestic appliances    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   22  male    2     own        moderate         moderate           1514
#
#    Duration  Purpose  Risk
# 0        15  repairs     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -             -        -
# 1   -   -   2       -                                -             -        -
# 2   -   -   -       -                                -             -        -
#
#                Purpose Risk
# 0  furniture/equipment    1
# 1                    -    1
# 2            education    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   37  male    1     own          little         moderate           1154
#
#    Duration   Purpose  Risk
# 0         9  radio/TV     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -        6797.0        -
# 1   -   -   -       -                                -       12050.0        -
# 2   -   -   -       -      quite rich                -             -     34.0
#
#   Purpose Risk
# 0       -    1
# 1       -    1
# 2       -    1
# Query instance (original outcome : 0)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   28  female    3     own        moderate             rich           2923
#
#    Duration Purpose  Risk
# 0        21     car     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -          little                -             -        -
# 1   -   -   -       -      quite rich                -             -        -
# 2   -   -   -       -                                -       13472.0        -
#
#                Purpose Risk
# 0  domestic appliances    1
# 1             radio/TV    1
# 2                    -    1
# Query instance (original outcome : 1)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   30  female    3     own                           little           7174
#
#    Duration   Purpose  Risk
# 0        42  radio/TV     1
# Diverse Counterfactual set (new outcome: 0.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -            rich                -             -        -
# 1   -   -   1       -               -                -       15775.0        -
# 2   -   -   2       -               -                -             -     54.0
#
#                Purpose Risk
# 0  domestic appliances    0
# 1                    -    0
# 2                    -    0
# Query instance (original outcome : 1)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   23  male    0     own                         moderate          14555
#
#    Duration Purpose  Risk
# 0         6     car     1
# Diverse Counterfactual set (new outcome: 0.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   3       -      quite rich                -             -        -
# 1   -   -   -       -      quite rich                -             -        -
# 2   -   -   -       -            rich                -             -     65.0
#
#   Purpose Risk
# 0       -    0
# 1       -    0
# 2       -    0
# Query instance (original outcome : 1)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   37  male    2    free          little                            1819
#
#    Duration    Purpose  Risk
# 0        36  education     1
# No counterfactuals found!
# Query instance (original outcome : 1)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   25  female    2     own                         moderate           2762
#
#    Duration              Purpose  Risk
# 0        12  furniture/equipment     1
# Diverse Counterfactual set (new outcome: 0.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   3       -               -                -             -        -
# 1   -   -   -    rent               -                -             -        -
# 2   -   -   -    free               -                -             -        -
#
#   Purpose Risk
# 0     car    0
# 1       -    0
# 2     car    0
# Query instance (original outcome : 0)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   19  female    1    rent            rich         moderate            983
#
#    Duration              Purpose  Risk
# 0        12  furniture/equipment     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -        8839.0        -
# 1   -   -   -       -                                -             -     49.0
# 2   -   -   -       -                                -       14789.0        -
#
#   Purpose Risk
# 0       -    1
# 1       -    1
# 2       -    1
# Query instance (original outcome : 1)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   27  male    2    rent                                            7980
#
#    Duration   Purpose  Risk
# 0        36  business     1
# No counterfactuals found!
# Query instance (original outcome : 0)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   22  female    1    rent          little                            1258
#
#    Duration              Purpose  Risk
# 0        12  furniture/equipment     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   3       -                                -             -        -
# 1   -   -   2       -               -                -             -        -
# 2   -   -   -       -                                -             -      4.0
#
#   Purpose Risk
# 0       -    1
# 1     car    1
# 2       -    1
# Query instance (original outcome : 1)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   26  male    3     own          little                            4463
#
#    Duration   Purpose  Risk
# 0        36  radio/TV     1
# No counterfactuals found!
# Query instance (original outcome : 1)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   38  male    2     own                                            3914
#
#    Duration   Purpose  Risk
# 0        48  business     1
# No counterfactuals found!
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   51  male    3    free          little           little           1164
#
#    Duration          Purpose  Risk
# 0         8  vacation/others     0
# No counterfactuals found!
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   39  male    2     own          little           little           2522
#
#    Duration   Purpose  Risk
# 0        30  radio/TV     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   0       -                                -       11029.0     21.0
# 1   -   -   2       -                                -             -     60.0
# 2   -   -   1       -                                -       11940.0        -
#
#                Purpose Risk
# 0  domestic appliances    1
# 1  domestic appliances    1
# 2  domestic appliances    1
# Query instance (original outcome : 1)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   41  male    1     own          little                             719
#
#    Duration    Purpose  Risk
# 0        12  education     1
# No counterfactuals found!
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   32  male    2    rent        moderate         moderate          11760
#
#    Duration    Purpose  Risk
# 0        39  education     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -     own                                -       12495.0        -
# 1   -   -   -     own                                -             -        -
# 2   -   -   -     own                                -        3338.0        -
#
#    Purpose Risk
# 0        -    1
# 1  repairs    1
# 2        -    1
# Query instance (original outcome : 1)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   22  female    2     own          little                            1808
#
#    Duration              Purpose  Risk
# 0        18  furniture/equipment     1
# Diverse Counterfactual set (new outcome: 0.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -    free               -                -             -     27.0
# 1   -   -   -    free               -                -        2073.0        -
# 2   -   -   1    rent               -                -             -        -
#
#   Purpose Risk
# 0       -    0
# 1       -    0
# 2       -    0
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   31  male    2     own        moderate         moderate           1449
#
#    Duration   Purpose  Risk
# 0         6  business     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -        2352.0        -
# 1   -   -   -       -                                -             -        -
# 2   -   -   -       -                                -             -     40.0
#
#   Purpose Risk
# 0       -    1
# 1       -    1
# 2       -    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   39  male    1    rent          little           little           2122
#
#    Duration Purpose  Risk
# 0        12     car     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -     own                                -             -        -
# 1   -   -   -     own                                -        1855.0        -
# 2   -   -   -     own                                -       13566.0        -
#
#                Purpose Risk
# 0  domestic appliances    1
# 1  domestic appliances    1
# 2  domestic appliances    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   33  male    2     own          little             rich           6289
#
#    Duration   Purpose  Risk
# 0        42  business     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -            rich                -             -        -
# 1   -   -   -       -                                -             -     71.0
# 2   -   -   -       -                                -             -     15.0
#
#     Purpose Risk
# 0  radio/TV    1
# 1         -    1
# 2         -    1
# Query instance (original outcome : 1)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   32  male    2     own          little                            1530
#
#    Duration Purpose  Risk
# 0        18     car     1
# No counterfactuals found!
# Query instance (original outcome : 0)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   58  female    1     own          little           little            385
#
#    Duration   Purpose  Risk
# 0        12  radio/TV     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -        1938.0        -
# 1   -   -   -       -                                -             -     56.0
# 2   -   -   -       -                                -             -      4.0
#
#                Purpose Risk
# 0  domestic appliances    1
# 1  domestic appliances    1
# 2  domestic appliances    1
# Query instance (original outcome : 0)
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   22  female    2    rent          little           little           3632
#
#    Duration Purpose  Risk
# 0        24     car     0
# No counterfactuals found!
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   37  male    2     own        moderate         moderate           3878
#
#    Duration Purpose  Risk
# 0        24     car     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -             -        -
# 1   -   -   -       -                                -       11733.0        -
# 2   -   -   -       -                                -        5248.0        -
#
#     Purpose Risk
# 0  radio/TV    1
# 1         -    1
# 2         -    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   50  male    3    free          little           little           7476
#
#    Duration    Purpose  Risk
# 0        48  education     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -     own                                -             -        -
# 1   -   -   -     own                                -             -        -
# 2   -   -   -     own                                -             -        -
#
#                Purpose Risk
# 0              repairs    1
# 1      vacation/others    1
# 2  domestic appliances    1
# Query instance (original outcome : 0)
#    Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   23  male    2     own          little         moderate            882
#
#    Duration   Purpose  Risk
# 0        13  radio/TV     0
# Diverse Counterfactual set (new outcome: 1.0)
#   Age Sex Job Housing Saving accounts Checking account Credit amount Duration  \
# 0   -   -   -       -                                -        7750.0        -
# 1   -   -   -       -                                -        2188.0        -
# 2   -   -   -       -                                -             -     25.0
#
#   Purpose Risk
# 0       -    1
# 1       -    1
# 2       -    1

# %% [markdown]
# ## MODEL #2

# %%
# Using sklearn backend
m2 = dice_ml.Model(model=clf_svm, backend="sklearn")
# Using method=random for generating CFs
exp2 = dice_ml.Dice(d, m, method="random")

# %%
e2 = exp2.generate_counterfactuals(df[4:7], total_CFs=3, desired_class="opposite")
e2.visualize_as_dataframe(show_only_changes=True)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-287-cef2316bd640> in <module>
# ----> 1 e2 = exp2.generate_counterfactuals(df[4:7], total_CFs=3, desired_class="opposite")
#       2 e2.visualize_as_dataframe(show_only_changes=True)
#
# ~/Desktop/DiCE/dice_ml/explainer_interfaces/explainer_base.py in generate_counterfactuals(self, query_instances, total_CFs, desired_class, desired_range, permitted_range, features_to_vary, stopping_threshold, posthoc_sparsity_param, proximity_weight, sparsity_weight, diversity_weight, categorical_penalty, posthoc_sparsity_algorithm, verbose, **kwargs)
#     156                 posthoc_sparsity_algorithm=posthoc_sparsity_algorithm,
#     157                 verbose=verbose,
# --> 158                 **kwargs)
#     159             cf_examples_arr.append(res)
#     160
#
# ~/Desktop/DiCE/dice_ml/explainer_interfaces/dice_random.py in _generate_counterfactuals(self, query_instance, total_CFs, desired_range, desired_class, permitted_range, features_to_vary, stopping_threshold, posthoc_sparsity_param, posthoc_sparsity_algorithm, sample_size, random_seed, verbose)
#      63         :returns: A CounterfactualExamples object that contains the dataframe of generated counterfactuals as an attribute.
#      64         """
# ---> 65         self.features_to_vary = self.setup(features_to_vary, permitted_range, query_instance, feature_weights=None)
#      66
#      67         if features_to_vary == "all":
#
# ~/Desktop/DiCE/dice_ml/explainer_interfaces/explainer_base.py in setup(self, features_to_vary, permitted_range, query_instance, feature_weights)
#     212             self.feature_range, feature_ranges_orig = self.data_interface.get_features_range(permitted_range)
#     213
# --> 214         self.check_query_instance_validity(features_to_vary, permitted_range, query_instance, feature_ranges_orig)
#     215
#     216         # check feature MAD validity and throw warnings
#
# ~/Desktop/DiCE/dice_ml/explainer_interfaces/explainer_base.py in check_query_instance_validity(self, features_to_vary, permitted_range, query_instance, feature_ranges_orig)
#     225
#     226             if feature not in self.data_interface.feature_names:
# --> 227                 raise ValueError("Feature", feature, "not present in training data!")
#     228
#     229         for feature in self.data_interface.categorical_feature_names:
#
# ValueError: ('Feature', 'Age', 'not present in training data!')
